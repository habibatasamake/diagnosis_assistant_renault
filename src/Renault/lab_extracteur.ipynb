# %%
from script_telecom import *

pd.set_option('display.max_rows', 50)
pd.set_option('display.max_columns', 30)
pd.set_option('display.max_colwidth', None)

# %%
extracteur = Extracteur_SCR(url = "doc-R-30iB.pdf")
# extracteur.extract_equipment()
extracteur.extract_defects(
    nom_modele_equipement="gemini-1.5-flash-002", 
    nom_modele_scr="gemini-1.5-flash-002", 
    start_page = 48, 
    end_page = 60
)
# Out:
# Overwriting cache for 0 11633
#                URL               equipment  page  \
# 0   doc-R-30iB.pdf  R-30iB Mate Controller    48
# 1   doc-R-30iB.pdf  R-30iB Mate Controller    48
# 2   doc-R-30iB.pdf  R-30iB Mate Controller    48
# 3   doc-R-30iB.pdf  R-30iB Mate Controller    48
# 4   doc-R-30iB.pdf  R-30iB Mate Controller    48
# ..             ...                     ...   ...
# 69  doc-R-30iB.pdf  R-30iB Mate Controller    60
# 70  doc-R-30iB.pdf  R-30iB Mate Controller    60
# 71  doc-R-30iB.pdf  R-30iB Mate Controller    60
# 72  doc-R-30iB.pdf  R-30iB Mate Controller    60
# 74  doc-R-30iB.pdf  R-30iB Mate Controller    60
#
#                                  symptom  \
# 0       ACAL-000 Fail to run DETECT Motn
# 1            ACAL-001 Robot is not ready
# 2            ACAL-002 Fail to fit circle
# 3         ACAL-003 Contact before search
# 4           ACAL-004 No contact detected
# ..                                   ...
# 69         MARRBERCD04121E Radius err %s
# ...
